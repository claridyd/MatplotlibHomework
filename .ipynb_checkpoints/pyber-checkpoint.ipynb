# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Read the city and ride data
city_df = pd.read_csv("city_data.csv")
ride_df = pd.read_csv("ride_data.csv")

# City dataframe
#city_df

# Ride dataframe
#ride_df

#combine the data into a single dataset
combo_data = pd.merge(ride_df, city_df, on="city")

#Display the combo data table for preview
combo_data
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1     Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2     Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3     Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4     Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
# 5     Lake Jonathanshire  2018-04-06 11:30:32  16.84  6164453571846
# 6     Lake Jonathanshire  2018-03-21 00:18:34  37.95  8353656732934
# 7     Lake Jonathanshire  2018-01-28 00:07:00   5.67  9756573174778
# 8     Lake Jonathanshire  2018-01-24 12:24:22  34.65  3319117904437
# 9     Lake Jonathanshire  2018-03-24 16:27:49  14.94  1670908453476
# 10    Lake Jonathanshire  2018-04-11 22:10:30  12.81  5999870428814
# 11    Lake Jonathanshire  2018-01-23 21:43:16  21.11  7711472105447
# 12    Lake Jonathanshire  2018-01-29 00:19:07  41.05  6649692036139
# ...

# %%
# what are the city types
city_type = combo_data["type"].unique()
#print(city_type)

#Group by City
city_grp = combo_data.groupby("city")


#Total number of rides per city
rides_per_city = city_grp["ride_id"].count()
#print(rides_per_city)

#Total number of drivers per city
drivers_city = city_grp["driver_count"].max()
#print(drivers_city)

#list city type
city_type = city_grp["type"].max()
#print(city_type)

#Average Fare per city
avg_fare = city_grp["fare"].mean()
#print(avg_fare)
#######################################################
# Create dataframe to hold data
#zipped_df = list(zip(rides_per_city, drivers_city, avg_fare))
#test1 = pd.DataFrame(zipped_df, columns = ["Rides per City", "Drivers per City", "Average Fare"])
#print(test1)

city_summary = pd.DataFrame({"Rides per City": rides_per_city,
                            "Drivers per City": drivers_city,
                            "Average Fare": avg_fare,
                            "City Type": city_type})
city_summary.head()
# Out:
#                Rides per City  Drivers per City  Average Fare City Type
# city
# Amandaburgh                18                12     24.641667     Urban
# Barajasview                22                26     25.332273     Urban
# Barronchester              16                11     36.422500  Suburban
# Bethanyland                18                22     32.956111  Suburban
# Bradshawfurt               10                 7     40.064000     Rural

# %%
#Get x, y for the city types
#Urban 
urban_summary = city_summary.loc[city_summary["City Type"]== "Urban"]
urban_rides = urban_summary["Rides per City"]
urban_drivers = urban_summary["Drivers per City"]
urban_avg = urban_summary["Average Fare"]
#Suburban
suburban_summary = city_summary.loc[city_summary["City Type"]== "Suburban"]
suburban_rides = suburban_summary["Rides per City"]
suburban_drivers = suburban_summary["Drivers per City"]
suburban_avg = suburban_summary["Average Fare"]
#Rural
rural_summary = city_summary.loc[city_summary["City Type"]== "Rural"]
rural_rides = rural_summary["Rides per City"]
rural_drivers = rural_summary["Drivers per City"]
rural_avg = rural_summary["Average Fare"]

# %%
# Create bubble plot
urban_plot = plt.scatter(urban_rides, urban_avg, s=urban_drivers*10, facecolors = "coral", alpha=0.75, edgecolors="black", linewidth=2, label = "Urban")
surb_plot = plt.scatter(suburban_rides, suburban_avg, s=suburban_drivers*10, facecolors = "SkyBlue", alpha=0.75, edgecolors="black", linewidth=2, label = "Suburban")
rural_plot = plt.scatter(rural_rides, rural_avg, s=rural_drivers*10, facecolors = "gold", alpha=0.75, edgecolors="black", linewidth=2, label = "Rural")
plt.xlabel("Total Number of Rides (Per City)")
plt.legend(title="City Types", handles=[urban_plot, surb_plot, rural_plot], loc="best")

plt.text(42,40,"Note: Circle size correlates with driver count per city")
plt.ylabel("Average Fare ($)" )
plt.title("Pyber Ride Sharing Data")
plt.grid()

# %%
#Group by City Type
citytype_grp = combo_data.groupby("type")
#Get total fares
total_fare = combo_data["fare"].sum()

#print(fare_tot)
fare_pct = fare_tot.apply(lambda x:100 * x / total_fare)
print(fare_pct)
# Out:
# type
# Rural        6.811493
# Suburban    30.463872
# Urban       62.724635
# Name: fare, dtype: float64

# %%
labels = ["Rural", "Suburban", "Urban"]
colors = ["gold", "skyblue", "coral"]
explode = (0,0,0.1)

# %%
plt.pie(fare_pct, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True)
plt.axis("equal")
plt.title("% of Total Fares by City Type")
# Out:
# Text(0.5, 1.0, '% of Total Fares by City Type')

# %%
#Get Ride per City type %
#Total rides
total_rides = combo_data["ride_id"].count()
print(total_rides)

ride_tot = citytype_grp["ride_id"].count()
#print(ride_tot)

ride_pct = ride_tot.apply(lambda x:100 * x / total_rides)
print(ride_pct)
# Out:
# 2375
# type
# Rural        5.263158
# Suburban    26.315789
# Urban       68.421053
# Name: ride_id, dtype: float64

# %%
plt.pie(ride_pct, explode=explode, labels=labels, colors = colors, autopct="%1.1f%%", shadow=True)
plt.axis("equal")
plt.title("% of Total Rides by City Type")
# Out:
# Text(0.5, 1.0, '% of Total Rides by City Type')

# %%
#Get Drivers by city type %
driver_data = combo_data[["city", "driver_count", "type"]]
sansdriverdups = driver_data.drop_duplicates()
total_drivers = sansdriverdups["driver_count"].sum()
print(total_drivers)
# Out:
# 2973

# %%
driver_grp = sansdriverdups.groupby("type")
driver_tot = driver_grp["driver_count"].sum()

driver_pct = driver_tot.apply(lambda x:100 * x / total_drivers)
print(driver_pct)
# Out:
# type
# Rural        2.623613
# Suburban    16.481668
# Urban       80.894719
# Name: driver_count, dtype: float64

# %%
plt.pie(driver_pct, explode=explode, labels=labels, colors = colors, autopct="%1.1f%%", shadow=True)
plt.axis("equal")
plt.title("% of Total Drivers by City Type")
# Out:
# Text(0.5, 1.0, '% of Total Drivers by City Type')
